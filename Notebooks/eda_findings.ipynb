# %% [markdown]
# 1. Mutual fund investments are concentrated in a few major states.
# 2. T30 cities contribute a larger share of investments than B30 cities.
# 3. Folio counts show consistent growth over time.
# 4. SIP inflows indicate increasing retail participation.
# 5. Certain fund categories dominate AUM.
# 6. Fund performance varies significantly across categories.
# 7. Expense ratios differ across schemes.
# 8. Several funds exhibit strong long-term returns.
# 9. Sector allocations are concentrated in a few industries.
# 10. Diversification opportunities exist among low-correlation funds.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("Database/bluestock_mf.db")

tables = pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)

print(tables)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sqlite3
#       2 import pandas as pd
#       3
# ----> 4 conn = sqlite3.connect("Database/bluestock_mf.db")
#       5
#       6 tables = pd.read_sql(
#       7     "SELECT name FROM sqlite_master WHERE type='table';",
#
# OperationalError: unable to open database file

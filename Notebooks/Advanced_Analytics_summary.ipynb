# %% [markdown]
# DAY 6 - Deliverable 6
#
# ## Risk Category Analysis
#
# Sector concentration analysis could not be performed because portfolio holdings data was unavailable.
#
# Instead, funds were classified and analysed using the available risk_category field from the fund master dataset.
#
# This provides a high-level view of the distribution of mutual funds across different risk profiles.

# %% [markdown]
# # Advanced Analytics Findings
#
# 1. Computed VaR and CVaR for all mutual funds to assess downside risk.
#
# 2. Generated rolling 90-day Sharpe Ratio trends for top ranked funds.
#
# 3. Performed investor cohort analysis and identified investment patterns by cohort year.
#
# 4. Evaluated SIP continuity and flagged investors with long contribution gaps.
#
# 5. Built a simple fund recommendation engine using risk-profile-based filtering.
#
# 6. Analysed risk-adjusted performance using Sharpe, Sortino, Alpha and Beta metrics.
#
# 7. Tracking error analysis highlighted benchmark-following efficiency among top funds.
#
# 8. CAGR and annualized returns showed long-term wealth creation potential.
#
# 9. Equity-oriented funds generally produced higher returns but also higher volatility.
#
# 10. Investor participation and SIP inflows increased steadily across recent cohorts.
